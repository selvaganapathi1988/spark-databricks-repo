# %% [markdown]
# ###1. Document the Notebook Using mark down %md :

# %% [markdown]
# #Working on Usecases
# <b>I am working on usecases to bring image from online with using inceptez usecase document.</b>\
# \
# ![](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)
# \
# \
# <i>Regards,\
# Selvaganapathi S</i>

# %% [markdown]
# ###2. Create a volume namely usage_metrics using <br />sql magic command %sql :

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.usage_metrics;

# %% [markdown]
# ###3. Create a child notebook "4_child_nb_dataload" and <br />write code to load data:

# %% [markdown]
# ###4. Call the notebook 4_child_nb_dataload using <br />the magic command %run :

# %%
# %run "/Workspace/Users/selvagopi5@gmail.com/Selva-WD36-local-notebooks/Usecases_notebook_fundamentals_workout/4_child_nb_dataload"

# %% [markdown]
# ###5.list the file is created in the given volume or not and<br /> do the head of this file using fs magic command %fs :

# %%
# %fs ls "/Volumes/workspace/default/usage_metrics"

# %%
# %fs head "dbfs:/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv"

# %% [markdown]
# ###6. Create a pyspark dataframe df1 reading the data from <br />the above file using pyspark magic command %python :

# %%
# %py
df1=spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
display(df1)

# %% [markdown]
# ###7. Write the above dataframe df1 data into a databricks table called<br /> 'default.mobile_os_usage' using pyspark magic command %python :

# %%
# %py
table_name="default.mobile_os_usage"
df1=spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
display(df1)

df1.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable(table_name)

# %% [markdown]
# ###8. Write sql query to display the data loaded into the table<br /> 'default.mobile_os_usage' using the pyspark magic command %python :

# %%
# %sql
select * from default.mobile_os_usage;

# %% [markdown]
# ###9.Create a python function to convert the given<br /> input to upper case :

# %%
# %py
name_input=("i am working on usecases")
#df1=str(df1)
name_upper=name_input.upper()
display(name_upper)

# %% [markdown]
# ###10. Install pandas library using the pip python magic  <br />command %pip :

# %%
# %pip install pandas

# %% [markdown]
# ###11. Import pandas, using pandas read_csv and display the<br /> output using the magic command %python :

# %%
# %py
import pandas as pd
#file_name="workspace.default.mobile_os_usage"
df = pd.read_csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
display(df)

# %% [markdown]
# ###12. echo "Magic commands tasks completed" using the linux <br />shell magic command %sh :

# %%
# %sh echo "Magic commands tasks completed"
